# %% [markdown]
# # SIRI cohort EDA

# %% [markdown]
# The aim of this study is to find predictors for the appearence of Immune Reconstitution Inflammatory Syndrome (IRIS) in patients treated con antiretroviral therapy (ART).

# %%
import pandas

# %%
data = pandas.read_csv("/home/carlos/scripts/vihCohort/data/TablaLPS_IL18_20180217.csv")
data.head()
# Out:
#    Numero_consecutivo  Expediente  Gender  LPS_pg_ml_W0  IL18_pg_ml  \
# 0                   1      156234  Hombre        76.613     2356.97
# 1                   5      156523  Hombre        42.217     1984.86
# 2                  12      157821  Hombre        53.348     2123.65
# 3                  14      157784  Hombre        64.217     1082.27
# 4                  16      158502  Hombre       147.551      559.72
#
#    TNFalfa_pg_ml_W0  IL10pg_ml_W0  IL6pg_ml_W0  IL8pg_ml_W0  CV_S000  \
# 0              3.70          3.30        11.87         6.07   732000
# 1              3.70          3.30         4.22        13.74  1000000
# 2              3.70          9.12         6.36        11.47   770000
# 3              3.70          4.01         2.50         4.26   132000
# 4             10.66          3.30         6.16        15.77  1000000
#
#         ...        CD8porcentajeS52  CocCD4_CD8_S52  CD4_S52  DeltaCD4_W52  \
# 0       ...                    42.0           0.323      216         178.0
# 1       ...                    50.0           0.327      327         312.0
# 2       ...                    60.0           0.192      183         177.0
# 3       ...                    71.0           0.100      120         115.0
# 4       ...                    37.0           0.468      439         404.0
#
#    DeltaCD4W52atleast150  CD4TCabove200_W052  CD4TCabove350_W052  \
# 0                      1                   1                   0
# 1                      1                   1                   0
# 2                      1                   0                   0
# 3                      0                   0                   0
# 4                      1                   1                   1
#
#    DeltaLogCV_W8  DeltaLogCV_W12  DeltaLogCV_W39
# 0          3.566           3.263         4.16603
# 1          1.807           3.290         4.30103
# 2          4.187           3.284         4.18703
# 3          3.422           3.422         3.42203
# 4          3.455           3.398         4.30103
#
# [5 rows x 98 columns]
